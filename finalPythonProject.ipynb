# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('stellarHost.csv')

x = df['st_mass']
y = df['sy_vmag']

coefficients = np.polyfit(x, y, degree)

polynomial = np.poly1d(coefficients)

y_fit = polynomial(x)

residuals = y - y_fit

error_bars = np.std(residuals)


plt.figure(figsize=(8, 6))
plt.scatter(x, y, label='Data')


plt.plot(x, polynomial(x), color='red', label='Line of Best Fit')


plt.errorbar(x, y_fit, yerr=error_bars, fmt='*', color='grey', label='Error Bars')

plt.title('Scatter Plot with Line of Best Fit and Error Bars')
plt.xlabel('Stellar Mass')
plt.ylabel('V-Magnitude')
plt.legend()
plt.grid(True)
plt.show()
print(polynomial)
# Out:
#
# -3.903 x + 15.12
